# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('./dual_model_statewise_similarity.csv')

# %%
df.head()
# Out:
#                          state  checkpoint_avg_similarity  \
# 0  andaman_and_nicobar_islands                   0.189799
# 1               andhra_pradesh                   0.180544
# 2            arunachal_pradesh                   0.205043
# 3                        assam                   0.183434
# 4                        bihar                   0.180484
#
#    checkpoint_similarity_of_avg_embedding  vanilla_avg_similarity  \
# 0                                0.241577                0.259571
# 1                                0.230225                0.279025
# 2                                0.245361                0.266375
# 3                                0.234863                0.269988
# 4                                0.223267                0.280147
#
#    vanilla_similarity_of_avg_embedding
# 0                             0.330566
# 1                             0.355713
# 2                             0.318604
# 3                             0.345703
# 4                             0.346436

# %%
max(df['checkpoint_avg_similarity'])-min(df['checkpoint_avg_similarity'])
# Out:
# 0.038925000000000015

# %%
max(df['vanilla_avg_similarity']) - min(df['vanilla_avg_similarity'])
# Out:
# 0.040142999999999984

# %%
max_val = max(df['checkpoint_avg_similarity'])
min_val = min(df['checkpoint_avg_similarity'])
range_val = max_val - min_val

# Calculate percentage difference
# Using the standard formula: (max - min) / min * 100
percentage_difference = (range_val / min_val) * 100

print(f"Max: {max_val:.6f}")
print(f"Min: {min_val:.6f}")
print(f"Range: {range_val:.6f}")
print(f"Percentage difference: {percentage_difference:.2f}%")
# Out:
# Max: 0.207931
# Min: 0.169006
# Range: 0.038925
# Percentage difference: 23.03%

# %%
max_val = max(df['vanilla_avg_similarity'])
min_val = min(df['vanilla_avg_similarity'])
range_val = max_val - min_val

# Calculate percentage difference
# Using the standard formula: (max - min) / min * 100
percentage_difference = (range_val / min_val) * 100

print(f"Max: {max_val:.6f}")
print(f"Min: {min_val:.6f}")
print(f"Range: {range_val:.6f}")
print(f"Percentage difference: {percentage_difference:.2f}%")
# Out:
# Max: 0.290638
# Min: 0.250495
# Range: 0.040143
# Percentage difference: 16.03%

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 8))

# Set up positions for bars
x_pos = np.arange(len(df))
width = 0.35

# Create bars
checkpoint_vals = df['checkpoint_avg_similarity']
vanilla_vals = df['vanilla_avg_similarity'] 

checkpoint_bars = plt.bar(x_pos - width/2, checkpoint_vals, 
                         width, label='New Model', alpha=0.7, color='blue')
vanilla_bars = plt.bar(x_pos + width/2, vanilla_vals, 
                      width, label='Old Model', alpha=0.7, color='orange')

# Add mean lines
plt.axhline(y=checkpoint_vals.mean(), color='blue', linestyle='--', linewidth=1.5, label='New Mean')
plt.axhline(y=vanilla_vals.mean(), color='orange', linestyle='--', linewidth=1.5, label='Old Mean')

# Customize the chart
plt.xlabel('States', fontsize=12)
plt.ylabel('Average Similarity', fontsize=12)
plt.title('Average Similarity to "an Indian person" - Checkpoint vs Vanilla Model', fontsize=14)
plt.xticks(x_pos, df['state'], rotation=45, ha='right')
plt.legend()
plt.grid(True, alpha=0.3)

# Add value labels on top of bars
for i, (c_val, v_val) in enumerate(zip(checkpoint_vals, vanilla_vals)):
    plt.text(i - width/2, c_val + 0.002, f'{c_val:.3f}', ha='center', va='bottom', fontsize=9)
    plt.text(i + width/2, v_val + 0.002, f'{v_val:.3f}', ha='center', va='bottom', fontsize=9)

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 8))

# Set up positions for bars
x_pos = np.arange(len(df))
width = 0.35

# Create bars
checkpoint_vals = df['checkpoint_avg_similarity']
vanilla_vals = df['vanilla_avg_similarity'] 

checkpoint_bars = plt.bar(x_pos - width/2, checkpoint_vals, 
                         width, label='New Model', alpha=0.7, color='blue')
# vanilla_bars = plt.bar(x_pos + width/2, vanilla_vals, 
                    #   width, label='Old Model', alpha=0.7, color='orange')

# Add mean lines
plt.axhline(y=checkpoint_vals.mean(), color='blue', linestyle='--', linewidth=1.5, label='New Mean')
# plt.axhline(y=vanilla_vals.mean(), color='orange', linestyle='--', linewidth=1.5, label='Old Mean')

# Customize the chart
plt.xlabel('States', fontsize=12)
plt.ylabel('Average Similarity', fontsize=12)
plt.title('Average Similarity to "an Indian person" - Checkpoint vs Vanilla Model', fontsize=14)
plt.xticks(x_pos, df['state'], rotation=45, ha='right')
plt.legend()
plt.grid(True, alpha=0.3)

# Add value labels on top of bars
for i, (c_val, v_val) in enumerate(zip(checkpoint_vals, vanilla_vals)):
    plt.text(i - width/2, c_val + 0.002, f'{c_val:.3f}', ha='center', va='bottom', fontsize=9)
    # plt.text(i + width/2, v_val + 0.002, f'{v_val:.3f}', ha='center', va='bottom', fontsize=9)

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 8))

# Set up positions for bars
x_pos = np.arange(len(df))
width = 0.35

# Create bars
checkpoint_vals = df['checkpoint_avg_similarity']
vanilla_vals = df['vanilla_avg_similarity'] 

# checkpoint_bars = plt.bar(x_pos - width/2, checkpoint_vals, 
                        #  width, label='New Model', alpha=0.7, color='blue')
vanilla_bars = plt.bar(x_pos + width/2, vanilla_vals, 
                      width, label='Old Model', alpha=0.7, color='orange')

# Add mean lines
# plt.axhline(y=checkpoint_vals.mean(), color='blue', linestyle='--', linewidth=1.5, label='New Mean')
plt.axhline(y=vanilla_vals.mean(), color='orange', linestyle='--', linewidth=1.5, label='Old Mean')

# Customize the chart
plt.xlabel('States', fontsize=12)
plt.ylabel('Average Similarity', fontsize=12)
plt.title('Average Similarity to "an Indian person" - Checkpoint vs Vanilla Model', fontsize=14)
plt.xticks(x_pos, df['state'], rotation=45, ha='right')
plt.legend()
plt.grid(True, alpha=0.3)

# Add value labels on top of bars
for i, (c_val, v_val) in enumerate(zip(checkpoint_vals, vanilla_vals)):
    # plt.text(i - width/2, c_val + 0.002, f'{c_val:.3f}', ha='center', va='bottom', fontsize=9)
    plt.text(i + width/2, v_val + 0.002, f'{v_val:.3f}', ha='center', va='bottom', fontsize=9)

plt.tight_layout()
plt.show()

# %%
avg_similarity_checkpoint = sum(df['checkpoint_avg_similarity']) / len(df)
avg_similarity_old = sum(df['vanilla_avg_similarity']) / len(df)

# %%
for idx, row in df.iterrows():
    old_val = row['vanilla_avg_similarity']
    new_val = row['checkpoint_avg_similarity']
    print(row['state'], new_val, old_val, (old_val-new_val)/old_val * 100 )
# Out:
# andaman_and_nicobar_islands -0.08159 0.259571 131.43263307534355
# andhra_pradesh -0.120985 0.279025 143.35991398620195
# arunachal_pradesh -0.081485 0.266375 130.59033317691225
# assam -0.117174 0.269988 143.39970665362904
# bihar -0.123972 0.280147 144.2524817328046
# chandigarh -0.100638 0.262831 138.2900038427735
# chhattisgarh -0.119079 0.281809 142.25521541185697
# dadra_and_nagar_haveli_and_daman_and_diu -0.090687 0.262537 134.5425597153925
# delhi -0.108581 0.265849 140.8431101866097
# goa -0.096652 0.26627 136.29849400983966
# gujarat -0.117485 0.284064 141.35863749014308
# haryana -0.109132 0.271969 140.1266320793914
# himachal_pradesh -0.101032 0.278325 136.30000898230486
# jammu_and_kashmir -0.09323 0.269994 134.53039697178454
# jharkhand -0.134965 0.274321 149.1996602520405
# karnataka -0.123844 0.273291 145.31579891031905
# kerala -0.131733 0.27381 148.11109893721923
# ladakh -0.073004 0.266897 127.35287395512127
# lakshadweep -0.106812 0.273193 139.09763427320613
# madhya_pradesh -0.112986 0.285464 139.57977188016702
# maharashtra -0.132113 0.278076 147.50967361440757
# manipur -0.101737 0.26126 138.94090178366378
# meghalaya -0.094494 0.267423 135.33503101827444
# mizoram -0.094708 0.250495 137.80833948781412
# nagaland -0.080451 0.261069 130.81599117474693
# odisha -0.123413 0.2831 143.59342988343343
# puducherry -0.123725 0.285936 143.27017234625933
# punjab -0.113594 0.278664 140.76378721327475
# rajasthan -0.107953 0.290638 137.1434568088137
# sikkim -0.087527 0.260147 133.64520828608443
# tamil_nadu -0.135197 0.284283 147.55718773194317
# telangana -0.133339 0.267953 149.76208514179726
# tripura -0.113653 0.263887 143.0688135451917
# uttar_pradesh -0.107678 0.283511 137.98018419038414
# uttarakhand -0.099553 0.276541 135.9993635663428
# west_bengal -0.133801 0.278402 148.06035876179052

# %%
import pandas as pd

# Compute relative change
df['rel_change_pct'] = (-df['vanilla_avg_similarity'] +df['checkpoint_avg_similarity']) 

# Sort by relative change
df_sorted = df.sort_values(by='rel_change_pct', ascending=False)

# Print output
for _, row in df_sorted.iterrows():
    print(row['state'], row['checkpoint_avg_similarity'], row['vanilla_avg_similarity'], row['rel_change_pct'])
# Out:
# nagaland 0.262367 0.272407 -0.010039999999999993
# lakshadweep 0.270415 0.281332 -0.01091700000000001
# arunachal_pradesh 0.266717 0.278362 -0.011645000000000016
# ladakh 0.266711 0.278692 -0.01198100000000002
# rajasthan 0.287745 0.300541 -0.01279600000000003
# andaman_and_nicobar_islands 0.259501 0.272678 -0.013176999999999994
# meghalaya 0.267266 0.281218 -0.01395200000000002
# sikkim 0.259864 0.274041 -0.014176999999999995
# mizoram 0.250321 0.264792 -0.014471000000000012
# tamil_nadu 0.283309 0.297823 -0.014514000000000027
# delhi 0.264819 0.279356 -0.014536999999999967
# gujarat 0.281697 0.296243 -0.014546000000000003
# uttar_pradesh 0.281331 0.295987 -0.014656000000000002
# kerala 0.273438 0.288123 -0.014685000000000004
# goa 0.264692 0.279425 -0.014732999999999996
# andhra_pradesh 0.277301 0.292225 -0.014923999999999993
# odisha 0.280674 0.296264 -0.015590000000000048
# west_bengal 0.276305 0.291971 -0.015665999999999958
# himachal_pradesh 0.276656 0.292393 -0.015737
# jammu_and_kashmir 0.267818 0.283746 -0.015927999999999998
# chandigarh 0.261097 0.277087 -0.015990000000000004
# dadra_and_nagar_haveli_and_daman_and_diu 0.259914 0.275954 -0.01604
# bihar 0.277425 0.293609 -0.01618400000000003
# puducherry 0.283493 0.299793 -0.01629999999999998
# karnataka 0.271233 0.287578 -0.016345
# chhattisgarh 0.278886 0.295341 -0.016454999999999997
# jharkhand 0.272565 0.289114 -0.01654899999999998
# assam 0.268021 0.284623 -0.016602000000000006
# madhya_pradesh 0.283014 0.299641 -0.016627000000000003
# maharashtra 0.275813 0.292966 -0.01715300000000003
# uttarakhand 0.273808 0.291029 -0.017220999999999986
# tripura 0.262127 0.279381 -0.01725399999999999
# manipur 0.259938 0.277206 -0.017268000000000006
# haryana 0.269438 0.286878 -0.01744000000000001
# telangana 0.266233 0.284043 -0.017809999999999993
# punjab 0.276632 0.295706 -0.019074000000000035

# %%
# x = None
x = np.load('./similarities_array.npy')

# %%
x.shape
# Out:
# (2923,)

# %%
df = pd.read_csv('./data/dataset_total.csv')

# %%
df['state'].unique()
# Out:
# array(['nagaland', 'dadra_and_nagar_haveli_and_daman_and_diu', 'punjab',
#        'uttarakhand', 'delhi', 'andhra_pradesh', 'manipur', 'jharkhand',
#        'tamil_nadu', 'jammu_and_kashmir', 'assam', 'rajasthan', 'tripura',
#        'karnataka', 'mizoram', 'puducherry', 'uttar_pradesh', 'sikkim',
#        'chhattisgarh', 'madhya_pradesh', 'arunachal_pradesh', 'odisha',
#        'chandigarh', 'goa', 'meghalaya', 'gujarat', 'lakshadweep',
#        'kerala', 'telangana', 'andaman_and_nicobar_islands', 'haryana',
#        'ladakh', 'maharashtra', 'himachal_pradesh', 'west_bengal',
#        'bihar'], dtype=object)

# %%
import re

# %%
import pandas as pd
import re

# Load your CSV
# df = pd.read_csv("your_file.csv")

# Function to normalize state names
def normalize_state(name: str) -> str:
    if pd.isna(name):
        return name
    # Lowercase
    name = name.lower()
    # Replace spaces with underscores
    name = re.sub(r"\s+", "_", name.strip())
    return name

# Apply to the column containing state names
df["state"] = df["state"].apply(normalize_state)

# Save cleaned CSV
df.to_csv("cleaned_file.csv", index=False)
